# %% [markdown]
# <a href="https://colab.research.google.com/github/achalweise/Project-2/blob/main/Project_2_Part_2_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Clean Up

# %%
house_prices = pd.read_csv('/content/HousePrices_HalfMil.csv')
house_prices.head()
# Out:
#    Area  Garage  FirePlace  Baths  ...  Glass Doors  Swiming Pool  Garden  Prices
# 0   164       2          0      2  ...            1             0       0   43800
# 1    84       2          0      4  ...            1             1       1   37550
# 2   190       2          4      4  ...            0             0       0   49500
# 3    75       2          4      4  ...            1             1       1   50075
# 4   148       1          4      2  ...            1             1       1   52400
#
# [5 rows x 16 columns]

# %%
#Checking for duplicates
house_prices.duplicated().sum()
#deleting unnecessary columns 
house_prices.drop(columns = ['Garage', 'FirePlace', 'Baths', 'White Marble', 'Black Marble', 'Indian Marble', 'Floors', 'City', 'Solar', 'Electric', 'Fiber', 'Glass Doors', 'Swiming Pool', 'Garden'])
# Out:
#         Area  Prices
# 0        164   43800
# 1         84   37550
# 2        190   49500
# 3         75   50075
# 4        148   52400
# ...      ...     ...
# 499995   128   55900
# 499996    30   29250
# 499997   174   51350
# 499998   121   62725
# 499999    46   32150
#
# [500000 rows x 2 columns]

# %%
#identifying missing data 
house_prices.isna().sum()
# Out:
# Area             0
# Garage           0
# FirePlace        0
# Baths            0
# White Marble     0
# Black Marble     0
# Indian Marble    0
# Floors           0
# City             0
# Solar            0
# Electric         0
# Fiber            0
# Glass Doors      0
# Swiming Pool     0
# Garden           0
# Prices           0
# dtype: int64

# %%
#identifying inconsistencies 
house_prices.describe()
# Out:
#                 Area         Garage  ...         Garden         Prices
# count  500000.000000  500000.000000  ...  500000.000000  500000.000000
# mean      124.929554       2.001290  ...       0.501646   42050.139350
# std        71.795363       0.817005  ...       0.499998   12110.237201
# min         1.000000       1.000000  ...       0.000000    7725.000000
# 25%        63.000000       1.000000  ...       0.000000   33500.000000
# 50%       125.000000       2.000000  ...       1.000000   41850.000000
# 75%       187.000000       3.000000  ...       1.000000   50750.000000
# max       249.000000       3.000000  ...       1.000000   77975.000000
#
# [8 rows x 16 columns]

# %%
#producing a univariate visual
house_prices['Prices'].hist(bins=20)
plt.title('House Prices')
plt.show()

# %%
#identify Outliers
house_prices.boxplot(column = 'Prices', grid = False)
plt.title('House Prices')
plt.show()

# %%
#Create a correlation heatmap
fig, ax = plt.subplots(figsize=(20,10))
sns.heatmap(house_prices.corr(), annot=True, ax=ax);

# %%
X = house_prices.drop(columns = 'Prices')
y = house_prices['Prices']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
